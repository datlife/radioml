# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import  multiprocessing  as mp
import time
import numpy as np
import commpy as cp
import tensorflow as tf
from commpy.channelcoding import Trellis


from deepcom.model import NRSCDecoder           # Neural Decoder Model
from deepcom.metrics import BER, BLER           # metrics to benchmark Neural Decoder Model
from deepcom.utils import corrupt_signal        # simulate a AWGN Channel

from deepcom.dataset import create_bsc_dataset  # Create synthetic dataset
from deepcom.dataset import data_genenerator    # data loader for Tensorflow

import  matplotlib.pyplot  as plt

# %%
# Number of training data
BLOCK_LEN = 100
NUM_TRAINING_DATA = 120000
NUM_TESTING_DATA  = 10000

# ######################
# Network Architectures
# ######################
NUM_LAYERS = 2
NUM_HIDDEN_UNITS = 400

# ##############################
# Hyper-parameters for training
# ##############################
BATCH_SIZE = 400       # depends on size of GPU, should be a factor of num_data
LEARNING_RATE = 0.001
DROPOUT_RATE= 0.7

# #######################
# Encoder Params
# #######################
CONSTRAINT_LEN = 3     # num of shifts in Conv. Encoder
TRACE_BACK_DEPTH = 15  # (?) a parameter Viterbi Encoder

G = np.array([[0o7, 0o5]]) 
M = np.array([CONSTRAINT_LEN - 1])
trellis = Trellis(M, G, feedback=0o7)

# %%
# Ref: Communication Algo via Deep Learning (page 5, last paragraph)
Error_Prob = 0.1

# ############################
# Create dataset 
# #############################
print('Creating training data....')
X_train, Y_train = create_bsc_dataset(
    NUM_TRAINING_DATA, 
    BLOCK_LEN, 
    trellis, 
    error_prob=Error_Prob, seed=2018)

print('Creating testing data....')
X_test, Y_test = create_bsc_dataset(
    NUM_TESTING_DATA, 
    BLOCK_LEN, 
    trellis, 
    error_prob=Error_Prob,  seed=1111)

print('Number of training sequences {}'.format(len(X_train)))
print('Number of testing sequences {}'.format(len(X_test)))
# Out:
# Creating training data....
# Creating testing data....
# Number of training sequences 120000
# Number of testing sequences 10000

# %% [markdown]
# ## Estimate Neural Decoder Optimal Performance
#
# * Since we learn in advance that **Viterbi is optimal solution for Block Error Rate** (BLER), we can compute what is the global minima (Optimal Solution).

# %%
def run_viterbi(message_bits, noisy_bits):
    decoded_bits = cp.channelcoding.viterbi_decode(
        coded_bits=noisy_bits.astype(float), 
        trellis=trellis,
        tb_depth=TRACE_BACK_DEPTH,
        decoding_type='hard')
    num_bit_errors_per_message = cp.utilities.hamming_dist(
        message_bits.astype(int),
        decoded_bits[:-int(M)].astype(int))
    return num_bit_errors_per_message

ORIGNAL_BITS = Y_test.reshape((-1, BLOCK_LEN))
NOISY_SIGNALS= X_test.reshape((-1, 2 * BLOCK_LEN + 4))
pool = mp.Pool(processes=mp.cpu_count())
try:
    error_prob = Error_Prob
    print('Estimating Optimal Neural Decoder Performance at Error Probability = %.2f ' % error_prob)
    t0 = time.time()
    viterbi_hamm_dists = pool.starmap(
        func=run_viterbi, 
        iterable=[(msg_bits, noisy) for msg_bits, noisy in zip(ORIGNAL_BITS,NOISY_SIGNALS)])
    t1 = time.time()

    # Compute BER and BLER 
    vi_ber = sum(viterbi_hamm_dists) / np.product(np.shape(Y_test))
    vi_bler = np.count_nonzero(viterbi_hamm_dists) / len(Y_test)        
    print("[BER] = %.3f [BLER] = %.3f -- %3.3f s" % 
            (vi_ber, vi_bler, t1 - t0))
except Exception as e:
    print(e)
finally:
    pool.close()
# Out:
# Estimating Optimal Neural Decoder Performance at Error Probability = 0.10
# [BER] = 0.067 [BLER] = 0.898 -- 36.344 s

# %% [markdown]
# ## Training Pipeline for Neural Decoder

# %%
tf.keras.backend.clear_session()

# Construct Neural Decoder
inputs = tf.keras.Input(shape=(None, 2))
outputs = NRSCDecoder(
    inputs, 
    is_training=True, 
    num_layers=NUM_LAYERS, 
    hidden_units=NUM_HIDDEN_UNITS, 
    dropout=DROPOUT_RATE)

model = tf.keras.Model(inputs, outputs)
model.compile(
    tf.keras.optimizers.SGD(lr=LEARNING_RATE, momentum=0.9, nesterov=True), 
    'binary_crossentropy', [BER, BLER])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None, 2)           0
# _________________________________________________________________
# bidirectional (Bidirectional (None, None, 800)         967200
# _________________________________________________________________
# batch_normalization (BatchNo (None, None, 800)         3200
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, None, 800)         2882400
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, 800)         3200
# _________________________________________________________________
# time_distributed (TimeDistri (None, None, 1)           801
# =================================================================
# Total params: 3,856,801
# Trainable params: 3,853,601
# Non-trainable params: 3,200
# _________________________________________________________________

# %%
def scheduler(epoch):
    if epoch < 20:
        return LEARNING_RATE
    elif 20 <= epoch < 40:
        return LEARNING_RATE/100.
    else:
       return LEARNING_RATE / 1000.

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=1)

# %%
# Set up Data Loader using tf.Dataset
X_train = X_train[:, :BLOCK_LEN, :]
X_test  = X_test[:,  :BLOCK_LEN, :]

train_set = data_genenerator(X_train, Y_train, BATCH_SIZE, shuffle=True)
test_set = data_genenerator(X_test, Y_test, BATCH_SIZE, shuffle=False)

# Save the best model
backup = tf.keras.callbacks.ModelCheckpoint(                     
  filepath='BiGRU_BSC.hdf5',
  monitor='val_BLER',
  save_best_only=True)


history = model.fit(
    train_set.make_one_shot_iterator(), 
    steps_per_epoch=len(X_train) //BATCH_SIZE, 
    validation_data=test_set.make_one_shot_iterator(),
    validation_steps= len(X_test) //BATCH_SIZE,
    callbacks=[backup, lr_scheduler],
    epochs=60)
# Out:
# Epoch 1/60
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# 300/300 [==============================] - 253s 843ms/step - loss: 0.3893 - BER: 0.1247 - BLER: 1.0000 - val_loss: 0.5499 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 2/60
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# 300/300 [==============================] - 245s 816ms/step - loss: 0.3472 - BER: 0.1009 - BLER: 1.0000 - val_loss: 0.3504 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 3/60
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# 300/300 [==============================] - 247s 822ms/step - loss: 0.3406 - BER: 0.1003 - BLER: 1.0000 - val_loss: 0.3268 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 4/60
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# 300/300 [==============================] - 248s 828ms/step - loss: 0.3375 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3260 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 5/60
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# 300/300 [==============================] - 248s 828ms/step - loss: 0.3356 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3254 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 6/60
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# 300/300 [==============================] - 249s 828ms/step - loss: 0.3342 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3249 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 7/60
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# 300/300 [==============================] - 249s 829ms/step - loss: 0.3333 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3246 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 8/60
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# 300/300 [==============================] - 249s 829ms/step - loss: 0.3324 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3244 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 9/60
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# 300/300 [==============================] - 248s 828ms/step - loss: 0.3319 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3242 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 10/60
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# 300/300 [==============================] - 248s 827ms/step - loss: 0.3313 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3241 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 11/60
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# 300/300 [==============================] - 247s 825ms/step - loss: 0.3308 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3239 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 12/60
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# 300/300 [==============================] - 248s 827ms/step - loss: 0.3305 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3238 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 13/60
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# 300/300 [==============================] - 249s 829ms/step - loss: 0.3301 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3237 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 14/60
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# 300/300 [==============================] - 248s 828ms/step - loss: 0.3299 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3236 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 15/60
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# 300/300 [==============================] - 248s 827ms/step - loss: 0.3296 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3235 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 16/60
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# 300/300 [==============================] - 249s 829ms/step - loss: 0.3294 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3235 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 17/60
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# 300/300 [==============================] - 249s 830ms/step - loss: 0.3291 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3234 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 18/60
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# 300/300 [==============================] - 249s 830ms/step - loss: 0.3290 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3234 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 19/60
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# 300/300 [==============================] - 249s 829ms/step - loss: 0.3288 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3232 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 20/60
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# 300/300 [==============================] - 248s 828ms/step - loss: 0.3287 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3232 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 21/60
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 1e-05.
# 300/300 [==============================] - 248s 827ms/step - loss: 0.3285 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3231 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 22/60
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 1e-05.
# 300/300 [==============================] - 248s 826ms/step - loss: 0.3285 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3231 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 23/60
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 1e-05.
# 300/300 [==============================] - 247s 824ms/step - loss: 0.3286 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3231 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 24/60
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 1e-05.
# 300/300 [==============================] - 248s 825ms/step - loss: 0.3285 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3231 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 25/60
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 1e-05.
# 300/300 [==============================] - 247s 823ms/step - loss: 0.3286 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3231 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 26/60
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 1e-05.
# 300/300 [==============================] - 247s 824ms/step - loss: 0.3285 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3231 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 27/60
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 1e-05.
# 300/300 [==============================] - 247s 825ms/step - loss: 0.3285 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3231 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 28/60
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 1e-05.
# 300/300 [==============================] - 248s 826ms/step - loss: 0.3286 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3231 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 29/60
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 1e-05.
# 300/300 [==============================] - 247s 824ms/step - loss: 0.3285 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3231 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 30/60
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1e-05.
# 300/300 [==============================] - 247s 824ms/step - loss: 0.3286 - BER: 0.1002 - BLER: 1.0000 - val_loss: 0.3231 - val_BER: 0.0992 - val_BLER: 1.0000
# Epoch 31/60
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1e-05.
# 200/300 [===================>..........] - ETA: 1:20 - loss: 0.3287 - BER: 0.1002 - BLER: 1.0000

# %%
# Count of the number of epochs# Count 
epochs = range(1, len(history.history['loss']) + 1)
# Visualize loss history
plt.figure(figsize=(8, 6))
plt.plot(epochs, history.history['loss'], 'r--')
plt.plot(epochs, history.history['val_loss'], 'b-')
plt.legend(['Training Loss', 'Test Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid()
plt.show()

# %% [markdown]
# ## Evaluate Decoder

# %%
# Load best-fit model
model = tf.keras.models.load_model('BiGRU_BSC.hdf5',{'BER': BER, 'BLER': BLER})

# %%
predictions = model.predict(X_test, batch_size=BATCH_SIZE).round()

hamming_dists = [cp.utilities.hamming_dist(
        x.astype(int),
        y.astype(int)
    ) for x, y in zip(predictions, Y_test)]

                        
print('BER: %.4f' % (np.sum(hamming_dists) /  np.product(np.shape(Y_test))))
print('BLER: %.4f'% (np.count_nonzero(hamming_dists) / len(Y_test)))
